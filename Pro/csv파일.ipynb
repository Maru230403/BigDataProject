# %%
import pandas as pd

# %%
df = pd.read_csv('data/2023/서울특별시 공공자전거 대여이력 정보_2306.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# d:\WorkSpace\BigDataProject\Pro\csv파일.ipynb 셀 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/WorkSpace/BigDataProject/Pro/csv%ED%8C%8C%EC%9D%BC.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv('data/2023/서울특별시 공공자전거 대여이력 정보_2306.csv', encoding='utf-8')
#
# File c:\Users\human\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\human\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
df.tail()
# Out:
#              자전거번호                 대여일시  대여 대여소번호         대여 대여소명  대여거치대  \
# 5085455  SPB-58542  2023-06-30 21:12:21       579        마장역 4번출구      0
# 5085456  SPB-65875  2023-06-30 21:11:10      4508  유원목동아파트 103동 앞      0
# 5085457  SPB-47327  2023-06-30 23:17:17      2724    (재)FITI시험연구원      0
# 5085458  SPB-51620  2023-06-30 22:26:14      1602          광운대역 앞      0
# 5085459  SPB-36822  2023-06-30 23:43:46       747        목동3단지 상가      0
#
#                         반납일시 반납대여소번호 반납대여소명 반납거치대  이용시간(분)  이용거리(M)    생년  성별  \
# 5085455  2023-07-02 13:05:27      \N     \N    \N      810      0.0  1996   F
# 5085456  2023-07-02 13:05:57      \N     \N    \N      810  35391.0  2006   F
# 5085457  2023-07-02 13:06:33      \N     \N    \N      810   1580.0  1994  \N
# 5085458  2023-07-02 13:07:01      \N     \N    \N      810   2835.0  2006   M
# 5085459  2023-07-02 13:07:45      \N     \N    \N      810  33122.0  2007   M
#
#         이용자종류  대여대여소ID 반납대여소ID
# ...
